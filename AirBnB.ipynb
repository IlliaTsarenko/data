# %% [markdown]
# <center><h1>Capstone Project Creation</h1></center>
# <center><h3>IBM SkillsBuild Europe Delivery - Data Analytics</h3></center>
#
#
# # Pre-requisite
#
# * Understanding of Python, Power BI or Tableau
# * Understanding of Data Cleaning
# * Understanding Data Visualization
#
# #### Level of Exercise: Intermediate
#
# #### Duration: approximately 3 hours

# %% [markdown]
# ### Data Analytics of Airbnb Data:
#
# #### Objective:
#
# In this exericise, you will be performing Data Analytics on an Open Dataset dataset coming from Airbnb. Some of the tasks include
# - Data Cleaning.
# - Data Transformation
# - Data Visualization.
#
# #### Overview of Airbnb Data:
#
# People's main criteria when visiting new places are reasonable accommodation and food. Airbnb (Air-Bed-Breakfast) is an online marketplace created to meet this need of people by renting out their homes for a short term. They offer this facility at a relatively lower price than hotels. Further people worldwide prefer the homely and economical service offered by them. They offer services across various geographical locations
#
# #### Dataset Source
#
# You can get the dataset for this assessment using the following link: https://www.kaggle.com/datasets/arianazmoudeh/airbnbopendata
#
# This dataset contains information such as the neighborhood offering these services, room type, price,avaliabilty, reviews, service fee, cancellation policy and rules to use the house. This analysis will help airbnb in improving its services.
#
# So all the best for your Data Analytics Journey on Airbnb data!!!

# %% [markdown]
# ## Task 1: Data Loading (Python)
#
# 1. Read the csv file and load it into a pandas dataframe.
# 2. Display the first five rows of your dataframe.
# 3. Display the data types of the columns.

# %%
#Import libraries
import pandas as pd
import os
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings 
warnings.filterwarnings('ignore')

# %%
# Read the csv file
rums = pd.read_csv('Airbnb_Open_Data.csv', encoding = 'latin1')

# %%
## Display the first 5 rows
rums.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# 0  40.64749 -73.97237  United States  ...       $193            10.0
# 1  40.75362 -73.98377  United States  ...        $28            30.0
# 2  40.80902 -73.94190  United States  ...       $124             3.0
# 3  40.68514 -73.95976  United States  ...        $74            30.0
# 4  40.79851 -73.94399  United States  ...        $41            10.0
#
#   number of reviews last review  reviews per month review rate number  \
# 0               9.0  10/19/2021               0.21                4.0
# 1              45.0   5/21/2022               0.38                4.0
# 2               0.0         NaN                NaN                5.0
# 3             270.0    7/5/2019               4.64                4.0
# 4               9.0  11/19/2018               0.10                3.0
#
#   calculated host listings count  availability 365  \
# 0                            6.0             286.0
# 1                            2.0             228.0
# 2                            1.0             352.0
# 3                            1.0             322.0
# 4                            1.0             289.0
#
#                                          house_rules license
# 0  Clean up and treat the home the way you'd like...     NaN
# 1  Pet friendly but please confirm with me if the...     NaN
# 2  I encourage you to use my kitchen, cooking and...     NaN
# 3                                                NaN     NaN
# 4  Please no smoking in the house, porch or on th...     NaN
#
# [5 rows x 26 columns]

# %%
## Display the data types
rums.dtypes
# Out:
# id                                  int64
# NAME                               object
# host id                             int64
# host_identity_verified             object
# host name                          object
# neighbourhood group                object
# neighbourhood                      object
# lat                               float64
# long                              float64
# country                            object
# country code                       object
# instant_bookable                   object
# cancellation_policy                object
# room type                          object
# Construction year                 float64
# price                              object
# service fee                        object
# minimum nights                    float64
# number of reviews                 float64
# last review                        object
# reviews per month                 float64
# review rate number                float64
# calculated host listings count    float64
# availability 365                  float64
# house_rules                        object
# license                            object
# dtype: object

# %% [markdown]
# ## Task 2a: Data Cleaning (Any Tool)
#
# 1. Drop some of the unwanted columns. These include `host id`, `id`, `country` and `country code` from the dataset.
# 2. State the reason for not including these columns for your Data Analytics.
#
# If using Python for this exercise, please include the code in the cells below. If using any other tool, please include screenshoots before and after the elimination of the columns.

# %%
rums.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# 0  40.64749 -73.97237  United States  ...       $193            10.0
# 1  40.75362 -73.98377  United States  ...        $28            30.0
# 2  40.80902 -73.94190  United States  ...       $124             3.0
# 3  40.68514 -73.95976  United States  ...        $74            30.0
# 4  40.79851 -73.94399  United States  ...        $41            10.0
#
#   number of reviews last review  reviews per month review rate number  \
# 0               9.0  10/19/2021               0.21                4.0
# 1              45.0   5/21/2022               0.38                4.0
# 2               0.0         NaN                NaN                5.0
# 3             270.0    7/5/2019               4.64                4.0
# 4               9.0  11/19/2018               0.10                3.0
#
#   calculated host listings count  availability 365  \
# 0                            6.0             286.0
# 1                            2.0             228.0
# 2                            1.0             352.0
# 3                            1.0             322.0
# 4                            1.0             289.0
#
#                                          house_rules license
# 0  Clean up and treat the home the way you'd like...     NaN
# 1  Pet friendly but please confirm with me if the...     NaN
# 2  I encourage you to use my kitchen, cooking and...     NaN
# 3                                                NaN     NaN
# 4  Please no smoking in the house, porch or on th...     NaN
#
# [5 rows x 26 columns]

# %%
# Removing columns host id, id, lat, long, country and country code from the dataset.
# We are not dealing with GIS here and no need to merge or join dataframes by ID. 
rums = rums.drop(['host id', 'id', 'lat', 'long', 'country','country code'], axis=1)

# %%
rums.head()
# Out:
#                                                NAME host_identity_verified  \
# 0                Clean & quiet apt home by the park            unconfirmed
# 1                             Skylit Midtown Castle               verified
# 2               THE VILLAGE OF HARLEM....NEW YORK !                    NaN
# 3                                               NaN            unconfirmed
# 4  Entire Apt: Spacious Studio/Loft by central park               verified
#
#   host name neighbourhood group neighbourhood instant_bookable  \
# 0  Madaline            Brooklyn    Kensington            False
# 1     Jenna           Manhattan       Midtown            False
# 2     Elise           Manhattan        Harlem             True
# 3     Garry            Brooklyn  Clinton Hill             True
# 4    Lyndon           Manhattan   East Harlem            False
#
#   cancellation_policy        room type  Construction year  price service fee  \
# 0              strict     Private room             2020.0  $966        $193
# 1            moderate  Entire home/apt             2007.0  $142         $28
# 2            flexible     Private room             2005.0  $620        $124
# 3            moderate  Entire home/apt             2005.0  $368         $74
# 4            moderate  Entire home/apt             2009.0  $204         $41
#
#    minimum nights  number of reviews last review  reviews per month  \
# 0            10.0                9.0  10/19/2021               0.21
# 1            30.0               45.0   5/21/2022               0.38
# 2             3.0                0.0         NaN                NaN
# 3            30.0              270.0    7/5/2019               4.64
# 4            10.0                9.0  11/19/2018               0.10
#
#    review rate number  calculated host listings count  availability 365  \
# 0                 4.0                             6.0             286.0
# 1                 4.0                             2.0             228.0
# 2                 5.0                             1.0             352.0
# 3                 4.0                             1.0             322.0
# 4                 3.0                             1.0             289.0
#
#                                          house_rules license
# 0  Clean up and treat the home the way you'd like...     NaN
# 1  Pet friendly but please confirm with me if the...     NaN
# 2  I encourage you to use my kitchen, cooking and...     NaN
# 3                                                NaN     NaN
# 4  Please no smoking in the house, porch or on th...     NaN

# %% [markdown]
# ## Task 2b: Data Cleaning (Python)
#
# - Check for missing values in the dataframe and display the count in ascending order. **If the values are missing, impute the values as per the datatype of the columns.**
# - Check whether there are any duplicate values in the dataframe and, if present, remove them.
# - Display the total number of records in the dataframe before and after removing the duplicates.

# %%
## Check for missing values in the dataframe and display the count in ascending order.
missing_values = rums.isnull().sum().sort_values(ascending=True)

# Display the result
print(missing_values)
# Out:
# room type                              0
# neighbourhood                         16
# neighbourhood group                   29
# cancellation_policy                   76
# instant_bookable                     105
# number of reviews                    183
# Construction year                    214
# price                                247
# NAME                                 250
# service fee                          273
# host_identity_verified               289
# calculated host listings count       319
# review rate number                   326
# host name                            406
# minimum nights                       409
# availability 365                     448
# reviews per month                  15879
# last review                        15893
# house_rules                        52131
# license                           102597
# dtype: int64

# %%
# Aproach 1
# object - mode, int or float - median
for col in rums.columns:
    if rums[col].dtype == 'O':
        rums[col].fillna(rums[col].mode()[0], inplace=True)
    else:
        rums[col].fillna(rums[col].median(), inplace=True)

# %%
## Check for missing values in the dataframe and display the count in ascending order.
missing_values = rums.isnull().sum().sort_values(ascending=True)

# Display the result
print(missing_values)
# Out:
# NAME                              0
# availability 365                  0
# calculated host listings count    0
# review rate number                0
# reviews per month                 0
# last review                       0
# number of reviews                 0
# minimum nights                    0
# service fee                       0
# price                             0
# Construction year                 0
# room type                         0
# cancellation_policy               0
# instant_bookable                  0
# neighbourhood                     0
# neighbourhood group               0
# host name                         0
# host_identity_verified            0
# house_rules                       0
# license                           0
# dtype: int64

# %%
## Approach 2
# float_columns = rums.select_dtypes(include='float64' or 'int').columns

# # Calculate the median of each float column
# median_values = rums[float_columns].median()

# # Replace missing values in float columns with the median
# rums[float_columns] = rums[float_columns].fillna(median_values)

# object_columns = rums.select_dtypes(include='object').columns
# # Calculate the median of each float column
# mode_values = rums[object_columns].mode().iloc[0]

# # Replace missing values in object columns with the mode
# rums[object_columns] =[object_columns].fillna(mode_values)

# %%
rums.shape
# Out:
# (102599, 20)

# %%
## Check whether there are any duplicate values in the dataframe and if present remove them.
duplicated_values = rums.duplicated().sum()
print(duplicated_values)
# Out:
# 3461

# %%
# duplicate_rows = rums[rums.duplicated()]
# print("Duplicate Rows except first occurrence:")
# print(duplicate_rows)

# %%
## Display the total number of records in the dataframe after removing the duplicates.
rums_no_dupl = rums.drop_duplicates(keep='first')
print("Total number of records after removing duplicates:", len(rums_no_dupl))
# Out:
# Total number of records after removing duplicates: 99138

# %% [markdown]
# ## Task 3: Data Transformation (Any Tool)
#
#
# - Rename the column `availability 365` to `days_booked`
# - Convert all column names to lowercase and replace the spaces in the column names with an underscore "_".
# - Remove the dollar sign and comma from the columns `price` and `service_fee`. If necessary, convert these two columns to the appropriate data type.
#
# If using Python for this exercise, please include the code in the cells below. If using any other tool, please include screenshoots of your work.

# %%
## Rename the columns.
rums_no_dupl.columns=['Name', 'host_identity_verified', 'host_name', 'neighbourhood_group',
       'neighbourhood', 'instant_bookable', 'cancellation_policy', 'room_type',
       'Construction_year', 'price', 'service_fee', 'minimum_nights',
       'number_of_reviews', 'last_review', 'reviews_per_month',
       'review_rate_number', 'host_listings_count',
       'days_booked', 'house_rules', 'license']

# %%
## Convert all column names to lowercase and replace the spaces with an underscore "_"
rums_no_dupl.columns = rums_no_dupl.columns.str.lower()
rums_no_dupl
# Out:
#                                                     name  \
# 0                     Clean & quiet apt home by the park
# 1                                  Skylit Midtown Castle
# 2                    THE VILLAGE OF HARLEM....NEW YORK !
# 3                                    Home away from home
# 4       Entire Apt: Spacious Studio/Loft by central park
# ...                                                  ...
# 102053               Cozy bright room near Prospect Park
# 102054         Private Bedroom with Amazing Rooftop View
# 102055     Pretty Brooklyn One-Bedroom for 2 to 4 people
# 102056        Room & private bathroom in historic Harlem
# 102057                                   Rosalee Stewart
#
#        host_identity_verified host_name neighbourhood_group  \
# 0                 unconfirmed  Madaline            Brooklyn
# 1                    verified     Jenna           Manhattan
# 2                 unconfirmed     Elise           Manhattan
# 3                 unconfirmed     Garry            Brooklyn
# 4                    verified    Lyndon           Manhattan
# ...                       ...       ...                 ...
# 102053            unconfirmed    Mariam            Brooklyn
# 102054               verified      Trey            Brooklyn
# 102055               verified   Michael            Brooklyn
# 102056            unconfirmed   Shireen           Manhattan
# 102057               verified   Stanley           Manhattan
#
#              neighbourhood  instant_bookable cancellation_policy  \
# 0               Kensington             False              strict
# 1                  Midtown             False            moderate
# 2                   Harlem              True            flexible
# 3             Clinton Hill              True            moderate
# 4              East Harlem             False            moderate
# ...                    ...               ...                 ...
# 102053            Flatbush              True            moderate
# 102054            Bushwick             False            flexible
# 102055  Bedford-Stuyvesant              True            moderate
# 102056              Harlem              True              strict
# 102057              Harlem             False            flexible
#
#               room_type  construction_year    price service_fee  \
# 0          Private room             2020.0    $966        $193
# 1       Entire home/apt             2007.0    $142         $28
# 2          Private room             2005.0    $620        $124
# 3       Entire home/apt             2005.0    $368         $74
# 4       Entire home/apt             2009.0    $204         $41
# ...                 ...                ...      ...         ...
# 102053     Private room             2012.0    $696         $41
# 102054     Private room             2012.0    $909         $41
# 102055  Entire home/apt             2012.0    $387         $41
# 102056     Private room             2012.0    $848         $41
# 102057  Entire home/apt             2011.0  $1,128         $41
#
#         minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0                 10.0                9.0  10/19/2021               0.21
# 1                 30.0               45.0   5/21/2022               0.38
# 2                  3.0                0.0   6/23/2019               0.74
# 3                 30.0              270.0    7/5/2019               4.64
# 4                 10.0                9.0  11/19/2018               0.10
# ...                ...                ...         ...                ...
# 102053             7.0               12.0   3/27/2019               0.44
# 102054             1.0               19.0   8/31/2017               0.72
# 102055             2.0               50.0   6/26/2019               3.12
# 102056             2.0                0.0   6/23/2019               0.74
# 102057             4.0               22.0   6/15/2019               0.85
#
#         review_rate_number  host_listings_count  days_booked  \
# 0                      4.0                  6.0        286.0
# 1                      4.0                  2.0        228.0
# 2                      5.0                  1.0        352.0
# 3                      4.0                  1.0        322.0
# 4                      3.0                  1.0        289.0
# ...                    ...                  ...          ...
# 102053                 5.0                  1.0          0.0
# 102054                 3.0                  2.0          0.0
# 102055                 4.0                  2.0        235.0
# 102056                 1.0                  1.0          0.0
# 102057                 4.0                  1.0        238.0
#
#                                               house_rules   license
# 0       Clean up and treat the home the way you'd like...  41662/AL
# 1       Pet friendly but please confirm with me if the...  41662/AL
# 2       I encourage you to use my kitchen, cooking and...  41662/AL
# 3                                                  #NAME?  41662/AL
# 4       Please no smoking in the house, porch or on th...  41662/AL
# ...                                                   ...       ...
# 102053  Shoes off Clean After yourself Turn Lights and...  41662/AL
# 102054                                             #NAME?  41662/AL
# 102055  * Check out: 10am * We made an effort to keep ...  41662/AL
# 102056  Each of us is working and/or going to school a...  41662/AL
# 102057  Please remember that this is a residential bui...  41662/AL
#
# [99138 rows x 20 columns]

# %%
## Remove the dollar sign and comma from the columns. If necessary, convert these two columns to the appropriate data type.
rums_no_dupl['price'] = rums_no_dupl['price'].astype(str)
rums_no_dupl['service_fee'] = rums_no_dupl['service_fee'].astype(str)
rums_no_dupl['price'] = rums_no_dupl['price'].str.replace(',', '').str.replace('$', '').astype(float)
rums_no_dupl['service_fee'] = rums_no_dupl['service_fee'].str.replace(',', '').str.replace('$', '').astype(float)

# %%
# # Remove the dollar sign and comma from the columns. If necessary, convert these two columns to the appropriate data type.
# def remove_signs(value):
#     return float(value.replace('$', '').replace(',', '').replace('', ''))

# rums_no_dupl['price'] = rums_no_dupl['price'].apply(lambda x: remove_signs(x))
# rums_no_dupl['service_fee'] = rums_no_dupl['service_fee'].apply(lambda x: remove_signs(x))

# %%
#checking for data consistency
unique_neighbourhood_group = rums_no_dupl['neighbourhood_group'].unique()
print(unique_neighbourhood_group)
# Out:
# ['Brooklyn' 'Manhattan' 'brookln' 'manhatan' 'Queens' 'Staten Island'
#  'Bronx']

# %%
#Replacing wrong coding 
replace_mapping = {'brookln': 'Brooklyn', 'manhatan': 'Manhattan'}
rums_no_dupl['neighbourhood_group'] = rums_no_dupl['neighbourhood_group'].replace(replace_mapping)

# Verify the changes
unique_neighbourhood_group = rums_no_dupl['neighbourhood_group'].unique()
print(unique_neighbourhood_group)
# Out:
# ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']

# %%
rums_no_dupl.host_identity_verified = rums_no_dupl.host_identity_verified.astype('category')
rums_no_dupl.neighbourhood_group = rums_no_dupl.neighbourhood_group.astype('category')
rums_no_dupl.neighbourhood = rums_no_dupl.neighbourhood.astype('category')
rums_no_dupl.cancellation_policy = rums_no_dupl.cancellation_policy.astype('category')
rums_no_dupl.room_type = rums_no_dupl.room_type.astype('category')
rums_no_dupl.construction_year = rums_no_dupl.construction_year.astype('category')

# %%
rums_no_dupl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99138 entries, 0 to 102057
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   name                    99138 non-null  object
#  1   host_identity_verified  99138 non-null  category
#  2   host_name               99138 non-null  object
#  3   neighbourhood_group     99138 non-null  category
#  4   neighbourhood           99138 non-null  category
#  5   instant_bookable        99138 non-null  bool
#  6   cancellation_policy     99138 non-null  category
#  7   room_type               99138 non-null  category
#  8   construction_year       99138 non-null  category
#  9   price                   99138 non-null  float64
#  10  service_fee             99138 non-null  float64
#  11  minimum_nights          99138 non-null  float64
#  12  number_of_reviews       99138 non-null  float64
#  13  last_review             99138 non-null  object
#  14  reviews_per_month       99138 non-null  float64
#  15  review_rate_number      99138 non-null  float64
#  16  host_listings_count     99138 non-null  float64
#  17  days_booked             99138 non-null  float64
#  18  house_rules             99138 non-null  object
#  19  license                 99138 non-null  object
# dtypes: bool(1), category(6), float64(8), object(5)
# memory usage: 11.4+ MB

# %% [markdown]
# ### Task 4: Exploratory Data Analysis (Any Tool)
#
# - List the count of various room types avaliable in the dataset.
# - Which room type has the most strict cancellation policy?
# - List the average price per neighborhood group, and highlight the most expensive neighborhood to rent from.
#
# If using Python for this exercise, please include the code in the cells below. If using any other tool, please include screenshoots of your work.

# %%
## List the count of various room types avaliable with Airbnb
room_type_counts = rums_no_dupl['room_type'].value_counts()
print(room_type_counts)
# Out:
# room_type
# Entire home/apt    51987
# Private room       44887
# Shared room         2149
# Hotel room           115
# Name: count, dtype: int64

# %%
unique_cancellation_policies = rums_no_dupl['cancellation_policy'].unique()
print(unique_cancellation_policies)
# Out:
# ['strict', 'moderate', 'flexible']
# Categories (3, object): ['flexible', 'moderate', 'strict']

# %%
## Which room type adheres to more strict cancellation policy == Entire home/apt
strict_cancellation = rums_no_dupl[rums_no_dupl['cancellation_policy'].isin(['strict'])]
room_type_counts = strict_cancellation['room_type'].value_counts()
print(room_type_counts)
# Out:
# room_type
# Entire home/apt    17238
# Private room       14936
# Shared room          718
# Hotel room            34
# Name: count, dtype: int64

# %%
## List the prices by neighborhood group and also mention which is the most expensive neighborhood group for rentals
mean_prices = rums_no_dupl.groupby('neighbourhood_group')['price'].mean().sort_values(ascending=False).round(2)

# Display mean prices
print(mean_prices)

# Determine the most expensive neighborhood group
most_expensive_group = mean_prices.idxmax()
print(f"The most expensive neighborhood group is: {most_expensive_group}")
# Out:
# neighbourhood_group
# Queens           628.67
# Brooklyn         625.47
# Bronx            625.27
# Staten Island    625.06
# Manhattan        621.66
# Name: price, dtype: float64
# The most expensive neighborhood group is: Queens

# %% [markdown]
# ## Task 5a: Data Visualization (Any Tool)
#
# * List the count of various room types avaliable with Airnb
# * Which room type adheres to more strict cancellation policy
# * List the prices by neighborhood group and also mention which is the most expensive neighborhood group for rentals
# * List the top 10 neighborhoods in the increasing order of their price with the help of a horizontal bar graph. Which is the cheapest neighborhood.
# * List the neighborhoods which offer short term rentals within 10 days. Illustrate with a bar graph
# * List the prices with respect to room type using a bar graph and also state your inferences.
# * Create a pie chart that shows  distribution of booked days for each neighborhood group .Which neighborhood has the highest booking percentage.
#
# If using Python for this exercise, please include the code in the cells below. If using any other tool, please include screenshoots of your work.

# %%
#List the count of various room types avaliable with Airnb
room_type_counts = rums_no_dupl['room_type'].value_counts()

# Display the count of various room types
print(room_type_counts)
# Out:
# room_type
# Entire home/apt    51987
# Private room       44887
# Shared room         2149
# Hotel room           115
# Name: count, dtype: int64

# %%
sns.set_style('whitegrid')
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27) #size of A4 paper
mylabels = list(rums_no_dupl.room_type.cat.categories)
sns.barplot(data=rums_no_dupl,x = mylabels, y=room_type_counts)
plt.title('Number of rooms by type', fontsize=35, color='DarkBlue', fontname='Arial')
plt.ylabel('Number', fontsize=20, color='DarkBlue')
plt.xlabel('Room type', fontsize=20, color='DarkBlue')

plt.yticks(fontsize=15)
plt.xticks(fontsize=15)

plt.show()

# %%
## List the prices by room type and also mention which is the most expensive room type for rentals
mean_prices_rums = rums_no_dupl.groupby('room_type')['price'].mean().round(2)
mean_prices_rums
# Out:
# room_type
# Entire home/apt    624.23
# Hotel room         666.39
# Private room       623.84
# Shared room        630.91
# Name: price, dtype: float64

# %%
# #Approach 1
# # Which room type is more expensive
# bars = mean_prices_rums.plot(kind='bar', figsize=(10, 6), color=['#FF6347', '#98FB98', '#87CEEB', '#FFD700'])

# # Finding the maximum value
# max_value = mean_prices_rums.max()

# plt.axhline(y=max_value, color='red', linestyle='--', label=f'Highest: {max_value}')

# plt.title('Average Price by Room type', fontsize=35, color='DarkBlue', fontname='Arial')
# plt.ylabel('Average Price', fontsize=20, color='DarkBlue')
# plt.xlabel('Room type', fontsize=20, color='DarkBlue')

# plt.yticks(fontsize=15)
# plt.xticks(fontsize=15)

# plt.show()

# %%
#Approach 2
strict_cancellation = rums_no_dupl[rums_no_dupl['cancellation_policy'].isin(['strict'])]
room_type_counts = strict_cancellation['room_type'].value_counts()

sns.set_style('whitegrid')
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27) #size of A4 paper 

mylabels = list(rums_no_dupl.room_type.cat.categories)
sns.barplot(data=rums_no_dupl, x=mylabels, y=room_type_counts, palette=['#FF6347', '#98FB98', '#87CEEB', '#FFD700'])

# Finding the maximum value
max_value = room_type_counts.max()

plt.axhline(y=max_value, color='red', linestyle='--', label=f'Highest: {max_value}')

plt.title('Cancelation policy', fontsize=35, color='DarkBlue', fontname='Arial')
plt.ylabel('Numbers', fontsize=20, color='DarkBlue')
plt.xlabel('Room type', fontsize=20, color='DarkBlue')

plt.yticks(fontsize=15)
plt.xticks(fontsize=15)

plt.show()

# %%
#List the prices by neighborhood group and also mention which is the most expensive neighborhood group for rentals
mean_prices = rums_no_dupl.groupby('neighbourhood_group')['price'].mean().sort_values(ascending=False).round(2)

sns.set_style('whitegrid')
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27) #size of A4 paper 

mylabels = list(rums_no_dupl.neighbourhood_group.cat.categories) 
sns.barplot(data=rums_no_dupl, x=mylabels, y=mean_prices, palette=['#FF6347', '#98FB98', '#87CEEB', '#FFD700', '#FFB6C1'])

# Finding the maximum value
max_value = mean_prices.max()

plt.axhline(y=max_value, color='red', linestyle='--', label=f'Highest: {max_value}')

plt.title('Average Price by Neighbourhood Groop', fontsize=35, color='DarkBlue', fontname='Arial')
plt.ylabel('Average Price', fontsize=20, color='DarkBlue')
plt.xlabel('Neighbourhood Group', fontsize=20, color='DarkBlue')

plt.yticks(fontsize=15)
plt.xticks(fontsize=15)

plt.show()
print(f"The most expensive neighborhood group is: {most_expensive_group}")
# Out:
# The most expensive neighborhood group is: Queens

# %%
#List the top 10 neighborhoods in the increasing order of their price with the help of a horizontal bar graph. Which is the cheapest neighborhood
mean_prices_neighborhood = rums_no_dupl.groupby('neighbourhood')['price'].mean().sort_values()
top_10_neighborhoods = rums_no_dupl.groupby('neighbourhood')['price'].mean().sort_values(ascending=True).head(10)
top_10_neighborhoods
# Out:
# neighbourhood
# Lighthouse Hill               107.666667
# Bay Terrace, Staten Island    306.000000
# Spuyten Duyvil                307.000000
# Breezy Point                  309.888889
# Rossville                     327.500000
# Richmondtown                  373.400000
# Castleton Corners             417.230769
# Emerson Hill                  443.800000
# West Farms                    463.166667
# Oakwood                       469.307692
# Name: price, dtype: float64

# %%
# horizontal bar
sns.set_style('whitegrid')
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)  # size of A4 paper

sns.barplot(data=rums_no_dupl, x=mean_prices_neighborhood, y=top_10_neighborhoods, orient='h', palette=['#FFB6C1','#FFD700', '#98FB98',  '#FFA07A',  '#87CEEB',  '#FF6347',  '#BA55D3',  '#F08080',  '#9370DB',  '#20B2AA'])
plt.title('Top 10 Neighborhoods by Average Price', fontsize=35, color='DarkBlue')
plt.xlabel('Average Price', fontsize=20, color='DarkBlue')
plt.ylabel('Neighborhood', fontsize=20, color='DarkBlue')
plt.show()

# %%
# horizontal bar
sns.set_style('whitegrid')
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)  # size of A4 paper

mylabels = list(rums_no_dupl.neighbourhood.cat.categories)

sns.barplot(data=rums_no_dupl, x=mean_prices_neighborhood, y=mylabels, orient='h', palette=['#FFB6C1','#FFD700', '#98FB98',  '#FFA07A',  '#87CEEB',  '#FF6347',  '#BA55D3',  '#F08080',  '#9370DB',  '#20B2AA'])
plt.title('Top 10 Neighborhoods by Average Price', fontsize=35, color='DarkBlue')
plt.xlabel('Average Price', fontsize=20, color='DarkBlue')
plt.ylabel('Neighborhood', fontsize=20, color='DarkBlue')
plt.show()

# %%
short_term_neighborhoods = rums_no_dupl[rums_no_dupl['minimum_nights'] <= 10]
neighborhood_counts = short_term_neighborhoods['neighbourhood'].value_counts()
short_term_neighborhoods
# Out:
#                                                     name  \
# 0                     Clean & quiet apt home by the park
# 2                    THE VILLAGE OF HARLEM....NEW YORK !
# 4       Entire Apt: Spacious Studio/Loft by central park
# 5              Large Cozy 1 BR Apartment In Midtown East
# 8                        Large Furnished Room Near B'way
# ...                                                  ...
# 102053               Cozy bright room near Prospect Park
# 102054         Private Bedroom with Amazing Rooftop View
# 102055     Pretty Brooklyn One-Bedroom for 2 to 4 people
# 102056        Room & private bathroom in historic Harlem
# 102057                                   Rosalee Stewart
#
#        host_identity_verified host_name neighbourhood_group  \
# 0                 unconfirmed  Madaline            Brooklyn
# 2                 unconfirmed     Elise           Manhattan
# 4                    verified    Lyndon           Manhattan
# 5                    verified  Michelle           Manhattan
# 8                    verified    Evelyn           Manhattan
# ...                       ...       ...                 ...
# 102053            unconfirmed    Mariam            Brooklyn
# 102054               verified      Trey            Brooklyn
# 102055               verified   Michael            Brooklyn
# 102056            unconfirmed   Shireen           Manhattan
# 102057               verified   Stanley           Manhattan
#
#              neighbourhood  instant_bookable cancellation_policy  \
# 0               Kensington             False              strict
# 2                   Harlem              True            flexible
# 4              East Harlem             False            moderate
# 5              Murray Hill              True            flexible
# 8           Hell's Kitchen              True              strict
# ...                    ...               ...                 ...
# 102053            Flatbush              True            moderate
# 102054            Bushwick             False            flexible
# 102055  Bedford-Stuyvesant              True            moderate
# 102056              Harlem              True              strict
# 102057              Harlem             False            flexible
#
#               room_type construction_year   price  service_fee  \
# 0          Private room            2020.0   966.0        193.0
# 2          Private room            2005.0   620.0        124.0
# 4       Entire home/apt            2009.0   204.0         41.0
# 5       Entire home/apt            2013.0   577.0        115.0
# 8          Private room            2005.0  1018.0        204.0
# ...                 ...               ...     ...          ...
# 102053     Private room            2012.0   696.0         41.0
# 102054     Private room            2012.0   909.0         41.0
# 102055  Entire home/apt            2012.0   387.0         41.0
# 102056     Private room            2012.0   848.0         41.0
# 102057  Entire home/apt            2011.0  1128.0         41.0
#
#         minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0                 10.0                9.0  10/19/2021               0.21
# 2                  3.0                0.0   6/23/2019               0.74
# 4                 10.0                9.0  11/19/2018               0.10
# 5                  3.0               74.0   6/22/2019               0.59
# 8                  2.0              430.0   6/24/2019               3.47
# ...                ...                ...         ...                ...
# 102053             7.0               12.0   3/27/2019               0.44
# 102054             1.0               19.0   8/31/2017               0.72
# 102055             2.0               50.0   6/26/2019               3.12
# 102056             2.0                0.0   6/23/2019               0.74
# 102057             4.0               22.0   6/15/2019               0.85
#
#         review_rate_number  host_listings_count  days_booked  \
# 0                      4.0                  6.0        286.0
# 2                      5.0                  1.0        352.0
# 4                      3.0                  1.0        289.0
# 5                      3.0                  1.0        374.0
# 8                      3.0                  1.0        180.0
# ...                    ...                  ...          ...
# 102053                 5.0                  1.0          0.0
# 102054                 3.0                  2.0          0.0
# 102055                 4.0                  2.0        235.0
# 102056                 1.0                  1.0          0.0
# 102057                 4.0                  1.0        238.0
#
#                                               house_rules   license
# 0       Clean up and treat the home the way you'd like...  41662/AL
# 2       I encourage you to use my kitchen, cooking and...  41662/AL
# 4       Please no smoking in the house, porch or on th...  41662/AL
# 5                       No smoking, please, and no drugs.  41662/AL
# 8       - Please clean up after yourself when using th...  41662/AL
# ...                                                   ...       ...
# 102053  Shoes off Clean After yourself Turn Lights and...  41662/AL
# 102054                                             #NAME?  41662/AL
# 102055  * Check out: 10am * We made an effort to keep ...  41662/AL
# 102056  Each of us is working and/or going to school a...  41662/AL
# 102057  Please remember that this is a residential bui...  41662/AL
#
# [82205 rows x 20 columns]

# %%
#List the neighborhoods which offer short term rentals within 10 days. Illustrate with a bar graph.
short_term_neighborhoods = rums_no_dupl[rums_no_dupl['minimum_nights'] <= 10]

mylabels2 = list(rums_no_dupl[rums_no_dupl['minimum_nights'] <= 10])


sns.set_style('whitegrid')
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27) #size of A4 paper 

sns.barplot(x=short_term_neighborhoods, y=mylabels2, palette='viridis')

plt.title('Short term rentals neighbourhood <= 10 days', fontsize=35, color='DarkBlue', fontname='Arial')
plt.ylabel('Neighbourhood', fontsize=20, color='DarkBlue')
plt.xlabel('Term', fontsize=20, color='DarkBlue')
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/l0/33t9h6856n38w3v3tvszc1_m0000gn/T/ipykernel_10826/4140399561.py in ?()
#       7 sns.set_style('whitegrid')
#       8 fig, ax = plt.subplots()
#       9 fig.set_size_inches(11.7, 8.27) #size of A4 paper
#      10
# ---> 11 sns.barplot(x=short_term_neighborhoods, y=mylabels2, palette='viridis')
#      12
#      13 plt.title('Short term rentals neighbourhood <= 10 days', fontsize=35, color='DarkBlue', fontname='Arial')
#      14 plt.ylabel('Neighbourhood', fontsize=20, color='DarkBlue')
#
# ~/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py in ?(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2751     # does not work in Series.agg (maybe a pandas bug?)
#    2752     if estimator is len:
#    2753         estimator = "size"
#    2754
# -> 2755     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                           estimator, errorbar, n_boot, units, seed,
#    2757                           orient, color, palette, saturation,
#    2758                           width, errcolor, errwidth, capsize, dodge)
#
# ~/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py in ?(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1526                  estimator, errorbar, n_boot, units, seed,
#    1527                  orient, color, palette, saturation, width,
#    1528                  errcolor, errwidth, capsize, dodge):
#    1529         """Initialize the plotter."""
# -> 1530         self.establish_variables(x, y, hue, data, orient,
#    1531                                  order, hue_order, units)
#    1532         self.establish_colors(color, palette, saturation)
#    1533         self.estimate_statistic(estimator, errorbar, n_boot, seed)
#
# ~/anaconda3/lib/python3.11/site-packages/seaborn/categorical.py in ?(self, x, y, hue, data, orient, order, hue_order, units)
#     540                     err = f"Could not interpret input '{var}'"
#     541                     raise ValueError(err)
#     542
#     543             # Figure out the plotting orientation
# --> 544             orient = infer_orient(
#     545                 x, y, orient, require_numeric=self.require_numeric
#     546             )
#     547
#
# ~/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py in ?(x, y, orient, require_numeric)
#    1580     TypeError: When dependent variable is not numeric, with `require_numeric`
#    1581
#    1582     """
#    1583
# -> 1584     x_type = None if x is None else variable_type(x)
#    1585     y_type = None if y is None else variable_type(y)
#    1586
#    1587     nonnumeric_dv_error = "{} orientation requires numeric `{}` variable."
#
# ~/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py in ?(vector, boolean_type)
#    1498     if pd.api.types.is_categorical_dtype(vector):
#    1499         return VariableType("categorical")
#    1500
#    1501     # Special-case all-na data, which is always "numeric"
# -> 1502     if pd.isna(vector).all():
#    1503         return VariableType("numeric")
#    1504
#    1505     # Special-case binary/boolean data, allow caller to determine
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py in ?(self)
#    1464     @final
#    1465     def __nonzero__(self) -> NoReturn:
# -> 1466         raise ValueError(
#    1467             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1468             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1469         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
#List the prices with respect to room type using a bar graph and also state your inferences.

sns.set_style('whitegrid')
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27) #size of A4 paper 

mylabels = list(rums_no_dupl.room_type.cat.categories)
sns.barplot(x=mylabels, y=mean_prices_rums, palette=['#FF6347', '#98FB98', '#87CEEB', '#FFD700'])

# Finding the maximum value
max_value = mean_prices_rums.max()

plt.axhline(y=max_value, color='red', linestyle='--', label=f'Highest: {max_value}')

plt.title('Average Price by Room type', fontsize=35, color='DarkBlue', fontname='Arial')
plt.ylabel('Average Price', fontsize=20, color='DarkBlue')
plt.xlabel('Room type', fontsize=20, color='DarkBlue')

plt.yticks(fontsize=15)
plt.xticks(fontsize=15)

plt.show()

# %%
#Create a pie chart that shows distribution of booked days for each neighborhood group. Which neighborhood has the highest booking percentage.
neighborhood_bookings = rums_no_dupl.groupby('neighbourhood_group')['days_booked'].mean().round(2)
total_bookings = neighborhood_bookings.sum()
booking_percentages = neighborhood_bookings / total_bookings * 100

sns.set_style('whitegrid')
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27) #size of A4 paper 

label_props = {'fontsize': 15, 'color': 'darkblue'}

p = plt.pie(booking_percentages, labels=booking_percentages.index, autopct='%1.1f%%', startangle=140,
            textprops=label_props, colors=plt.cm.Paired.colors)
plt.title('Booking Distribution by Neighborhood Group', fontsize=20, color='DarkBlue')
plt.show()

# %% [markdown]
# ## Task 5b: Data Visualization (Any Tool)
#
# * Does service price and room price have an impact on each other. Illustrate this relationship with a scatter plot and state your inferences
# * Using a line graph show in which year the maximum construction of rooms took place.
#
# If using Python for this exercise, please include the code in the cells below. If using any other tool, please include screenshoots of your work.

# %%
#Does service price and room price have an impact on each other. Illustrate this relationship with a scatter plot and state your inferences
# g = sns.FacetGrid(rums_no_dupl, row = 'price', col = 'service_fee', hue = 'room_type')
# kws = dict(s=50, linewidth = 0.5, edgecolor = 'black')
# g = g.map(plt.scatter, 'service_fee', 'price', **kws)

j = sns.scatterplot(data = rums_no_dupl, x='service_fee', y='price', hue='room_type')

# %%
plt.scatter(rums_no_dupl.price, rums_no_dupl.service_fee)

# %%
#Using a line graph show in which year the maximum construction of rooms took place.
room_counts = rums_no_dupl.construction_year.value_counts()
sns.lineplot(data = rums_no_dupl, x='construction_year', y=room_counts,)
# Out:
# <Axes: xlabel='construction_year', ylabel='count'>

# %% [markdown]
# ## Task 5c: Data Visualization (Any Tool)
#
# * With the help of box plots illustrate the following
#  * Effect of Review Rate number on price
#  * Effect of host identity verified on price
#
# If using Python for this exercise, please include the code in the cells below. If using any other tool, please include screenshoots of your work.

# %%
#With the help of box plots illustrate effect of Review Rate number on price
v = sns.boxplot(data = rums_no_dupl, x = 'review_rate_number', y = 'price')

# %%
#With the help of box plots illustrate effect of of host identity verified on price

v = sns.boxplot(data = rums_no_dupl, x = 'host_identity_verified', y = 'price')
